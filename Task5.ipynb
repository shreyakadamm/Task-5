# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.cluster import KMeans

# %%
np.random.seed(0)
n_samples = 1000

# %%
road_conditions = np.random.choice(['Dry', 'Wet', 'Icy'], size=n_samples)

# %%
weather_conditions = np.random.choice(['Clear', 'Rainy', 'Snowy'], size=n_samples)

# %%
time_of_day = np.random.randint(0, 24, size=n_samples)

# %%
latitude = np.random.uniform(40, 41, size=n_samples)
longitude = np.random.uniform(-74, -73, size=n_samples)

# %%
severity = np.random.randint(1, 6, size=n_samples)

# %%
data = pd.DataFrame({
    'road_condition': road_conditions,
    'weather': weather_conditions,
    'time_of_day': time_of_day,
    'latitude': latitude,
    'longitude': longitude,
    'severity': severity
})

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='road_condition', data=data, color= "pink" )
plt.title('Distribution of Road Conditions')
plt.xlabel('Road Condition')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='weather', data=data, color= "yellow" )
plt.title('Distribution of Weather Conditions')
plt.xlabel('Weather Condition')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.histplot(data['time_of_day'], bins=24, kde=True, color= "hot pink")
plt.title('Distribution of Time of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Frequency')
plt.show()

# %%
X = data[['latitude', 'longitude']]
kmeans = KMeans(n_clusters=5, random_state=0).fit(X)
data['cluster'] = kmeans.labels_

# %%
plt.figure(figsize=(10, 8))
sns.scatterplot(x='longitude', y='latitude', hue='cluster', data=data, palette='viridis', alpha=0.7,color= "red")
plt.title('Accident Hotspots')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend(title='Cluster')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='time_of_day', data=data, color='orange')
plt.title('Accidents by Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Number of Accidents')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='road_condition', y='severity', data=data,color= "green")
plt.title('Impact of Road Conditions on Accident Severity')
plt.xlabel('Road Condition')
plt.ylabel('Severity')
plt.show()
